# %%
from dotenv import load_dotenv
import os
import pandas as pd
load_dotenv()
import pickle as pk
import numpy as np
from pathlib import Path
base_dir = os.getenv('BASEDIR')

from tqdm import tqdm
tqdm.pandas()

from lightgbm import LGBMClassifier
from itertools import chain, combinations

# %%
import pandas as pd
import os 
import re
import numpy as np
from tqdm import tqdm

from sklearn.model_selection import cross_val_predict, StratifiedKFold
from sklearn.metrics import roc_auc_score, f1_score
from sklearn.datasets import make_classification

import os
from collections import defaultdict

# %%
granularities = ['_per_user'] #, '_per_episode','_per_post'
# 
datasets = ['qanda','ausvotes','socialsense','riot','parler']
fr_groundtruths =['USER_FR', 'URLa_FR', 'URLb_FR']
lr_groundtruths = ['hashtag','URL_LR','POLITICIAN_LR']
features = ['use']

# %%
performance = {dataset : {} for dataset in datasets}
gt_f1 = {dataset : {} for dataset in datasets}

# %%
import itertools
def all_combinations(l):
    return(itertools.product(l, repeat=2))

# %%
granularity = '_per_user'
feature = 'use'
ground_truth = 'URL_LR'
for train, test in itertools.chain(all_combinations(datasets)):
    train_path = os.path.join(base_dir,'data','03_processed',train,'ground_truth', train+'_'+ground_truth+'_'+granularity+'.pk')
    if not os.path.exists(train_path):
        continue
    test_path = os.path.join(base_dir,'data','03_processed',test,'ground_truth', test+'_'+ground_truth+'_'+granularity+'.pk')
    if not os.path.exists(test_path):
        continue
#         print(train, test)
    def load_vector(fp):
        with open(fp, 'rb') as rf:
            vec = pk.load(rf)
        return vec

    y_train = load_vector(train_path).values
    mask_train = y_train >= 0

    y_test = load_vector(test_path).values
    mask_test = y_test >= 0
    if any(mask_train):            
        y_train = y_train[mask_train]
        fp_train = os.path.join(base_dir,'data','03_processed',train,'features', train+'_'+feature+'_'+granularity+'.pk')
        X_train = load_vector(fp_train)
        X_train = X_train[mask_train]

        y_test = y_test[mask_test]
        fp_test = os.path.join(base_dir,'data','03_processed',test,'features', test+'_'+feature+'_'+granularity+'.pk')
        X_test = load_vector(fp_test)
        X_test = X_test[mask_test]



        
        if train == test:
            et = LGBMClassifier(n_estimators=100, min_data_in_leaf=500,colsample_bytree=0.8, class_weight='balanced', n_jobs=-1)
            skf = StratifiedKFold(n_splits=5, shuffle=True)
            preds = cross_val_predict(et, X_train, y_train, cv=skf, method='predict_proba')
        else:
            et = LGBMClassifier(n_estimators=100, min_data_in_leaf=500,colsample_bytree=0.8, class_weight='balanced', n_jobs=-1)
            et.fit(X_train,y_train)
            preds = et.predict_proba(X_test)
        if train in fr_groundtruths:
            preds = preds[:,1]
        # evaluating the model
        print(train, test)
        print('Area under the ROC Curve:', roc_auc_score(y_test, preds, multi_class='ovo'))

        performance[train][test] = roc_auc_score(y_test, preds, multi_class='ovo')
#             except Exception as e:
#                 print('Failed for:', train, test)
# Out:
# [LightGBM] [Warning] min_data_in_leaf is set=500, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=500
# [LightGBM] [Warning] min_data_in_leaf is set=500, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=500
# [LightGBM] [Warning] min_data_in_leaf is set=500, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=500
# [LightGBM] [Warning] min_data_in_leaf is set=500, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=500
# [LightGBM] [Warning] min_data_in_leaf is set=500, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=500
# qanda qanda
# Area under the ROC Curve: 0.911644419152328
# [LightGBM] [Warning] min_data_in_leaf is set=500, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=500
# qanda ausvotes
# Area under the ROC Curve: 0.630199447597955
# [LightGBM] [Warning] min_data_in_leaf is set=500, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=500
# qanda socialsense
# Area under the ROC Curve: 0.6395426739773102
# [LightGBM] [Warning] min_data_in_leaf is set=500, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=500
# qanda riot
# Area under the ROC Curve: 0.5936224148458504
# [LightGBM] [Warning] min_data_in_leaf is set=500, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=500
# qanda parler
# Area under the ROC Curve: 0.5719277561673823
# [LightGBM] [Warning] min_data_in_leaf is set=500, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=500
# ausvotes qanda
# Area under the ROC Curve: 0.7510923755873019
# [LightGBM] [Warning] min_data_in_leaf is set=500, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=500
# [LightGBM] [Warning] min_data_in_leaf is set=500, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=500
# [LightGBM] [Warning] min_data_in_leaf is set=500, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=500
# [LightGBM] [Warning] min_data_in_leaf is set=500, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=500
# [LightGBM] [Warning] min_data_in_leaf is set=500, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=500
# ausvotes ausvotes
# Area under the ROC Curve: 0.7901830742448253
# [LightGBM] [Warning] min_data_in_leaf is set=500, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=500
# ausvotes socialsense
# Area under the ROC Curve: 0.6374490697445556
# [LightGBM] [Warning] min_data_in_leaf is set=500, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=500
# ausvotes riot
# Area under the ROC Curve: 0.6068276298548714
# [LightGBM] [Warning] min_data_in_leaf is set=500, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=500
# ausvotes parler
# Area under the ROC Curve: 0.5703988490359518
# [LightGBM] [Warning] min_data_in_leaf is set=500, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=500
# socialsense qanda
# Area under the ROC Curve: 0.705270536611384
# [LightGBM] [Warning] min_data_in_leaf is set=500, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=500
# socialsense ausvotes
# Area under the ROC Curve: 0.5962401637202727
# [LightGBM] [Warning] min_data_in_leaf is set=500, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=500
# [LightGBM] [Warning] min_data_in_leaf is set=500, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=500
# [LightGBM] [Warning] min_data_in_leaf is set=500, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=500
# [LightGBM] [Warning] min_data_in_leaf is set=500, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=500
# [LightGBM] [Warning] min_data_in_leaf is set=500, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=500
# socialsense socialsense
# Area under the ROC Curve: 0.8245442274897039
# [LightGBM] [Warning] min_data_in_leaf is set=500, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=500
# socialsense riot
# Area under the ROC Curve: 0.5911633906594169
# [LightGBM] [Warning] min_data_in_leaf is set=500, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=500
# socialsense parler
# Area under the ROC Curve: 0.5675632289298644
# [LightGBM] [Warning] min_data_in_leaf is set=500, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=500
# riot qanda
# Area under the ROC Curve: 0.6561773990720671
# [LightGBM] [Warning] min_data_in_leaf is set=500, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=500
# riot ausvotes
# Area under the ROC Curve: 0.6053864715059275
# [LightGBM] [Warning] min_data_in_leaf is set=500, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=500
# riot socialsense
# Area under the ROC Curve: 0.6678602322652217
# [LightGBM] [Warning] min_data_in_leaf is set=500, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=500
# [LightGBM] [Warning] min_data_in_leaf is set=500, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=500
# [LightGBM] [Warning] min_data_in_leaf is set=500, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=500
# [LightGBM] [Warning] min_data_in_leaf is set=500, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=500
# [LightGBM] [Warning] min_data_in_leaf is set=500, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=500
# riot riot
# Area under the ROC Curve: 0.7617800750837912
# [LightGBM] [Warning] min_data_in_leaf is set=500, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=500
# riot parler
# Area under the ROC Curve: 0.6421023574976845
# [LightGBM] [Warning] min_data_in_leaf is set=500, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=500
# parler qanda
# Area under the ROC Curve: 0.5907775109525701
# [LightGBM] [Warning] min_data_in_leaf is set=500, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=500
# parler ausvotes
# Area under the ROC Curve: 0.5399825999769904
# [LightGBM] [Warning] min_data_in_leaf is set=500, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=500
# parler socialsense
# Area under the ROC Curve: 0.6361426534666762
# [LightGBM] [Warning] min_data_in_leaf is set=500, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=500
# parler riot
# Area under the ROC Curve: 0.6224729613155521
# [LightGBM] [Warning] min_data_in_leaf is set=500, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=500
# [LightGBM] [Warning] min_data_in_leaf is set=500, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=500
# [LightGBM] [Warning] min_data_in_leaf is set=500, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=500
# [LightGBM] [Warning] min_data_in_leaf is set=500, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=500
# [LightGBM] [Warning] min_data_in_leaf is set=500, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=500
# parler parler
# Area under the ROC Curve: 0.7151739563862929

# %%
col_order = datasets
performance_df =  pd.DataFrame(performance).reindex(index=col_order, columns=col_order)

# %%
performance_df.to_csv('./cross_dataset_auc.csv')
